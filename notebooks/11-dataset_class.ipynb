# %%
import pandas as pd
import numpy as np

# %%
past_dog_infos = pd.read_csv("../data/processed/05_dog_infos_engineered.csv")
race_headers = pd.read_csv("../data/processed/09_graded_a_race_header.csv")
race_stats = pd.read_csv("../data/processed/10_all_race_infos.csv")

# %%
past_dog_infos_isna = past_dog_infos.isna().sum()
race_headers_isna = race_headers.isna().sum()
race_stats_isna = race_stats.isna().sum()
